# %%
# !pip install pymongo
# Out:
# Requirement already satisfied: pymongo in c:\users\gurgi\anaconda3\envs\ethos_env\lib\site-packages (4.16.0)
# Requirement already satisfied: dnspython<3.0.0,>=2.6.1 in c:\users\gurgi\anaconda3\envs\ethos_env\lib\site-packages (from pymongo) (2.8.0)

# %%
import pandas as pd
from pymongo import MongoClient

# 1. Connect to your warehouse
client = MongoClient("mongodb://localhost:27017/")
db = client["ethos_db"]
collection = db["raw_transactions"]

# 2. Convert MongoDB data to a Pandas Table
data = list(collection.find())
df = pd.DataFrame(data)

# 3. Peek at the data
print(f"Total Transactions Loaded: {len(df)}")
df.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 2
#       1 import pandas as pd
# ----> 2 from pymongo import MongoClient
#       4 # 1. Connect to your warehouse
#       5 client = MongoClient("mongodb://localhost:27017/")
#
# ModuleNotFoundError: No module named 'pymongo'
